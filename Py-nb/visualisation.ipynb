# %% [markdown]
# # visualisation
#
# Use the "Run" button to execute the code.

# %%
print('This is a notebook for visualisation with matplot.lib and seaborn')
# Out:
# This is a notebook for visualisation with matplot.lib and seaborn

# %%
# Out:
# [jovian] Updating notebook "prabhat-himika/visualisation" on https://jovian.com
# [jovian] Committed successfully! https://jovian.com/prabhat-himika/visualisation
# 'https://jovian.com/prabhat-himika/visualisation'

# %%
# !pip install matplotlib seaborn --upgrade --quiet

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Line chart
# - line chart - plt.plot(x,y)
# - plt.plot(y)
# - to assign labels
#
#     - plt.xlabel('label for X-axis')
#     - plt.ylabel('label for Y-axis')

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

plt.plot(years, yield_apples)
plt.xlabel("Years")
plt.ylabel("Yield of apples")
# Out:
# Text(0, 0.5, 'Yield of apples')

# %% [markdown]
# #### Plotting multiple lines

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]
plt.plot(years, apples)
plt.plot(years, oranges)
plt.xlabel("Years")
plt.ylabel("Yield (tonnes per hectare)")
# Out:
# Text(0, 0.5, 'Yield (tonnes per hectare)')

# %%
plt.plot(years,apples)
plt.plot(years, oranges)
plt.title("Crop yields in Kanto")
# wrong - plt.legend('Apples','Oranges')

plt.legend(['Apples','Oranges'])

# %%
plt.plot(years,apples, marker='o')
plt.plot(years, oranges, marker='x')
plt.title("Crop yields in Kanto")
# wrong - plt.legend('Apples','Oranges')

plt.legend(['Apples','Oranges'])

# %% [markdown]
# ### Styling Lines and Markers
#
# The `plt.plot` function supports many arguments for styling lines and markers:
#
# - `color` or `c`: Set the color of the line ([supported colors](https://matplotlib.org/3.1.0/gallery/color/named_colors.html))
# - `linestyle` or `ls`: Choose between a solid or dashed line
# - `linewidth` or `lw`: Set the width of a line
# - `markersize` or `ms`: Set the size of markers
# - `markeredgecolor` or `mec`: Set the edge color for markers
# - `markeredgewidth` or `mew`: Set the edge width for markers
# - `markerfacecolor` or `mfc`: Set the fill color for markers
# - `alpha`: Opacity of the plot
# - `marker`: can be 'o' - round, 's'- square, 'x' -cross
#
# Check out the documentation for `plt.plot` to
#
# #### Shorthand
# The `fmt` argument provides a shorthand for specifying the marker shape, line style, and line color. It can be provided as the third argument to `plt.plot`.
#
# ```
# fmt = '[marker][line][color]'
# ```
#
# Eg, plt.plot(years, apples, 's--b')
#
#
# learn more: [https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot) .

# %%
plt.plot(years, apples,marker='s',c='chartreuse',ls='--',lw = '1',ms = 10, mec='b', mew='3',alpha=0.8)
plt.plot(years, oranges, 'o--r')

plt.title("Yield year per year")
plt.legend(['apples', 'oranges','oranges'])

# %%
#Changing figure size - place it before the plot 
plt.figure(figsize =(5,5))
plt.plot(years, oranges, 'xb',ms ='4')

# %%
sns.set_style("whitegrid")
plt.plot(years, oranges, 'xb')

# %%
sns.set_style("darkgrid")
plt.plot(years, oranges, 'xb')

# %%
plt.plot(years, oranges, 'x')
plt.rcParams['font.size'] = 14
plt.rcParams['figure.figsize'] = (9, 5)
# plt.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# #### Scatterplot
#
# sns.scatterplot(x =,y=, hue=colname,s=100)
#
# s=size
#
# hue = give the dots a separate color as per one parameter

# %%
# Load data into a Pandas dataframe
flowers_df = sns.load_dataset("iris")
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(flowers_df.sepal_length, flowers_df.sepal_width)

# %%
sns.scatterplot(x=flowers_df.sepal_length,y=flowers_df.sepal_width,hue=flowers_df.species, s=100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
# Since Seaborn uses Matplotlib's plotting 
#functions internally, we can use functions 
# like plt.figure and plt.title to modify the figure.
plt.figure(figsize=(12, 6))
plt.title('Sepal Dimensions')

sns.scatterplot(x=flowers_df.sepal_length, 
                y=flowers_df.sepal_width, 
                hue=flowers_df.species,
                s=100);

# %%
# Seaborn has in-built support for pandas dataframes
# we can also simply pass the columns and later use 
# 'data' arg to specify the dataframe

sns.scatterplot(x='sepal_length', 
                y='sepal_width', 
                hue='species',
                s=100,
                data=flowers_df);

# %% [markdown]
# #### Histogram
#
# plt.hist()

# %%
# Out:
# (array([ 4.,  7., 22., 24., 37., 31., 10., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
# specifying the number of bins
plt.hist(flowers_df.sepal_width, bins = 5)
# Out:
# (array([11., 46., 68., 21.,  4.]),
#  array([2.  , 2.48, 2.96, 3.44, 3.92, 4.4 ]),
#  <BarContainer object of 5 artists>)

# %%
import numpy as np
# arange returns evenly spaced intervals
plt.hist(flowers_df.sepal_width, bins =np.arange(2,5,0.25))
# Out:
# (array([ 4.,  7., 22., 24., 50., 18., 13.,  8.,  3.,  1.,  0.]),
#  array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#         4.75]),
#  <BarContainer object of 11 artists>)

# %%
plt.hist(flowers_df.sepal_width, bins = [1,2, 4, 5.5])
# Out:
# (array([  0., 146.,   4.]),
#  array([1. , 2. , 4. , 5.5]),
#  <BarContainer object of 3 artists>)

# %%
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

plt.hist(setosa_df.sepal_width, alpha=0.4, bins=np.arange(2, 5, 0.25));
plt.hist(versicolor_df.sepal_width, alpha=0.4, bins=np.arange(2, 5, 0.25));

# %%
plt.hist([setosa_df.sepal_width,versicolor_df.sepal_width, virginica_df.sepal_width]
         , bins=np.arange(2, 5, 0.25),
         stacked = True);

plt.legend(['setosa',' versicolor', 'virginica'])

# %% [markdown]
# #### Bar chart
#
# plt.bar(x,y);

# %%
import matplotlib.pyplot as plt 
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

plt.bar(years,apples)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(years, oranges, bottom=apples)
#lol
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(years,apples)
plt.bar(years, oranges, bottom=apples)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# #### Bar plots with averages

# %%
import seaborn as sns
tips_df = sns.load_dataset("tips");
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
avg_df = tips_df.groupby("day")[['total_bill','day']].mean()
avg_df
# Out:
#       total_bill
# day
# Thur   17.682742
# Fri    17.151579
# Sat    20.441379
# Sun    21.410000

# %%
plt.bar(tips_df.day,tips_df.total_bill)
# Out:
# <BarContainer object of 244 artists>

# %%
sns.barplot(x='day', y='total_bill', hue = 'sex' ,data=tips_df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x=tips_df.day, y=tips_df.total_bill)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "prabhat-himika/visualisation" on https://jovian.com
# [jovian] Committed successfully! https://jovian.com/prabhat-himika/visualisation
# 'https://jovian.com/prabhat-himika/visualisation'

# %% [markdown]
# #### Heatmap
#
# sns.heatmap(df);

# %%
flights_df = sns.load_dataset("flights").pivot("month", "year", "passengers")
flights_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
plt.title("No. of passengers(1000s)")
sns.heatmap(flights_df)
# Out:
# <AxesSubplot:title={'center':'No. of passengers(1000s)'}, xlabel='year', ylabel='month'>

# %% [markdown]
# `fmt` is used to select the datatype of the contents of the cells in the heatmap
#
# display the actual values in each block by specifying `annot=True` and using the `cmap` argument to change the color palette.Ex: Blues, Greens, PiYG.

# %%
plt.title("No. of passengers (1000s)")
sns.heatmap(flights_df, fmt = 'd', annot=True , cmap  = 'Blues')
# Out:
# <AxesSubplot:title={'center':'No. of passengers (1000s)'}, xlabel='year', ylabel='month'>

# %% [markdown]
# #### Images

# %%
from urllib.request import urlretrieve
urlretrieve('https://i.imgur.com/SkPbq.jpg','chart.jpg')
# Out:
# ('chart.jpg', <http.client.HTTPMessage at 0x7f3523a55220>)

# %%
from PIL import Image
import numpy as np
img = Image.open('chart.jpg')
plt.imshow(img)

# %%
plt.grid(True)
plt.imshow(img)
plt.title("a data science meme")
# plt.axis('off')
# Out:
# Text(0.5, 1.0, 'a data science meme')

# %% [markdown]
# An image loaded using PIL is a numpy array

# %%
img_array = np.array(img)
img_array.shape
# Out:
# (481, 640, 3)

# %%
plt.imshow(img_array[125:325 , 105:305])
# plt.axis('off')

# %%
# Plotting multiple charts in a grid
flowers_df = sns.load_dataset("iris")
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

fig, axes = plt.subplots(2, 3, figsize=(16, 8))

# Use the axes for plotting
axes[0,0].plot(years, apples, 's-b')
axes[0,0].plot(years, oranges, 'o--r')
axes[0,0].set_xlabel('Year')
axes[0,0].set_ylabel('Yield (tons per hectare)')
axes[0,0].legend(['Apples', 'Oranges']);
axes[0,0].set_title('Crop Yields in Kanto')


# Pass the axes into seaborn
axes[0,1].set_title('Sepal Length vs. Sepal Width')
sns.scatterplot(x=flowers_df.sepal_length, 
                y=flowers_df.sepal_width, 
                hue=flowers_df.species, 
                s=100, 
                ax=axes[0,1]);

# Use the axes for plotting
axes[0,2].set_title('Distribution of Sepal Width')
axes[0,2].hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width], 
         bins=np.arange(2, 5, 0.25), 
         stacked=True);

axes[0,2].legend(['Setosa', 'Versicolor', 'Virginica']);

# Pass the axes into seaborn
axes[1,0].set_title('Restaurant bills')
sns.barplot(x='day', y='total_bill', hue='sex', data=tips_df, ax=axes[1,0]);

# Pass the axes into seaborn
axes[1,1].set_title('Flight traffic')
sns.heatmap(flights_df, cmap='Blues', ax=axes[1,1]);

# Plot an image using the axes
axes[1,2].set_title('Data Science Meme')
axes[1,2].imshow(img)
axes[1,2].grid(False)
axes[1,2].set_xticks([])
axes[1,2].set_yticks([])

plt.tight_layout(pad=2);

# %%
# Out:
# [jovian] Updating notebook "prabhat-himika/visualisation" on https://jovian.com
# [jovian] Committed successfully! https://jovian.com/prabhat-himika/visualisation
# 'https://jovian.com/prabhat-himika/visualisation'
