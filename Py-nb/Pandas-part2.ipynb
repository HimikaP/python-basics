# %% [markdown]
# #### Querying and sorting rows
#
# - `covid_df.new_cases.sum()` - Computing the sum of values in a column or series
# - `covid_df[covid_df.new_cases > 1000]` - Querying a subset of rows satisfying the chosen criteria using boolean expressions
# - `df['pos_rate'] = df.new_cases/df.new_tests` - Adding new columns by combining data from existing columns
# - `covid_df.drop('positive_rate')` - Removing one or more columns from the data frame
# - `sort_values` - Sorting the rows of a data frame using column values
# - `covid_df.at[172, 'new_cases'] = ...` - Replacing a value within the data frame

# %%
from urllib.request import urlretrieve

# %%
italy_covid_url = 'https://gist.githubusercontent.com/aakashns/f6a004fa20c84fec53262f9a8bfee775/raw/f309558b1cf5103424cef58e2ecb8704dcd4d74c/italy-covid-daywise.csv'

urlretrieve(italy_covid_url, 'italy-covid-daywise.csv')
# Out:
# ('italy-covid-daywise.csv', <http.client.HTTPMessage at 0x1f38fc826a0>)

# %%
import pandas as pd

# %%
covid_df = pd.read_csv('italy-covid-daywise.csv')

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
high_cases = covid_df.new_cases > 1000
high_cases
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 243     True
# 244     True
# 245    False
# 246    False
# 247     True
# Name: new_cases, Length: 248, dtype: bool

# %%
from IPython.display import display 
with pd.option_context('display.max_rows' , 100):
    display(covid_df[covid_df.new_cases > 1000])
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# 74   2020-03-14     2547.0       252.0        NaN
# 75   2020-03-15     3497.0       173.0        NaN
# 76   2020-03-16     2823.0       370.0        NaN
# 77   2020-03-17     4000.0       347.0        NaN
# 78   2020-03-18     3526.0       347.0        NaN
# 79   2020-03-19     4207.0       473.0        NaN
# 80   2020-03-20     5322.0       429.0        NaN
# 81   2020-03-21     5986.0       625.0        NaN
# 82   2020-03-22     6557.0       795.0        NaN
# 83   2020-03-23     5560.0       649.0        NaN
# 84   2020-03-24     4789.0       601.0        NaN
# 85   2020-03-25     5249.0       743.0        NaN
# 86   2020-03-26     5210.0       685.0        NaN
# ...

# %%
# or
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
positive_rate = covid_df.new_cases.sum() / covid_df.new_tests.sum()
positive_rate
# Out:
# 0.06344614829548428

# %%
high_ratio_df = covid_df[ covid_df.new_cases / covid_df.new_tests > positive_rate]
high_ratio_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 111  2020-04-20     3047.0       433.0     7841.0
# 112  2020-04-21     2256.0       454.0    28095.0
# 114  2020-04-23     3370.0       437.0    37083.0
# 116  2020-04-25     3021.0       420.0    38676.0
# 117  2020-04-26     2357.0       415.0    24113.0
# 118  2020-04-27     2324.0       260.0    26678.0
# 124  2020-05-03     1900.0       474.0    27047.0
# 128  2020-05-07     1444.0       369.0    13665.0

# %%
# The result of performing an operation on two columns is a new series.
# we add this series to add a new column to the data frame

covid_df['positive_rate'] = covid_df.new_cases / covid_df.new_tests
covid_df

# to add a new col

covid_df["new_col"] = 1
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests  positive_rate  new_col
# 0    2019-12-31        0.0         0.0        NaN            NaN        1
# 1    2020-01-01        0.0         0.0        NaN            NaN        1
# 2    2020-01-02        0.0         0.0        NaN            NaN        1
# 3    2020-01-03        0.0         0.0        NaN            NaN        1
# 4    2020-01-04        0.0         0.0        NaN            NaN        1
# ..          ...        ...         ...        ...            ...      ...
# 243  2020-08-30     1444.0         1.0    53541.0       0.026970        1
# 244  2020-08-31     1365.0         4.0    42583.0       0.032055        1
# 245  2020-09-01      996.0         6.0    54395.0       0.018311        1
# 246  2020-09-02      975.0         8.0        NaN            NaN        1
# 247  2020-09-03     1326.0         6.0        NaN            NaN        1
#
# [248 rows x 6 columns]

# %%
# gives error 
# covid_df["something"]

# %%
# to delete a column 
covid_df.drop(columns = ['new_col'], inplace = True)

# when using inplace=False (which is the default behaviour) the dataframe operation returns a copy of the dataframe, leaving the original data intact. 
# when inplace = True, it changes the original form of the dataframe

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests  new_col
# 0    2019-12-31        0.0         0.0        NaN        1
# 1    2020-01-01        0.0         0.0        NaN        1
# 2    2020-01-02        0.0         0.0        NaN        1
# 3    2020-01-03        0.0         0.0        NaN        1
# 4    2020-01-04        0.0         0.0        NaN        1
# ..          ...        ...         ...        ...      ...
# 243  2020-08-30     1444.0         1.0    53541.0        1
# 244  2020-08-31     1365.0         4.0    42583.0        1
# 245  2020-09-01      996.0         6.0    54395.0        1
# 246  2020-09-02      975.0         8.0        NaN        1
# 247  2020-09-03     1326.0         6.0        NaN        1
#
# [248 rows x 5 columns]

# %%
# Sorting rows

covid_df.sort_values('new_cases' , ascending = False).head(10)
# Out:
#           date  new_cases  new_deaths  new_tests
# 82  2020-03-22     6557.0       795.0        NaN
# 87  2020-03-27     6153.0       660.0        NaN
# 81  2020-03-21     5986.0       625.0        NaN
# 89  2020-03-29     5974.0       887.0        NaN
# 88  2020-03-28     5959.0       971.0        NaN
# 83  2020-03-23     5560.0       649.0        NaN
# 80  2020-03-20     5322.0       429.0        NaN
# 85  2020-03-25     5249.0       743.0        NaN
# 90  2020-03-30     5217.0       758.0        NaN
# 86  2020-03-26     5210.0       685.0        NaN

# %%
covid_df.sort_values('new_tests', ascending = True).tail(10)
# Out:
#            date  new_cases  new_deaths  new_tests
# 103  2020-04-12     4694.0       619.0        NaN
# 104  2020-04-13     4092.0       431.0        NaN
# 105  2020-04-14     3153.0       564.0        NaN
# 106  2020-04-15     2972.0       604.0        NaN
# 107  2020-04-16     2667.0       578.0        NaN
# 108  2020-04-17     3786.0       525.0        NaN
# 109  2020-04-18     3493.0       575.0        NaN
# 110  2020-04-19     3491.0       480.0        NaN
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN

# %%
covid_df.loc[165:173]
# Out:
#            date  new_cases  new_deaths  new_tests
# 165  2020-06-13      163.0        56.0    32880.0
# 166  2020-06-14      346.0        78.0    29545.0
# 167  2020-06-15      338.0        44.0    17463.0
# 168  2020-06-16      301.0        26.0    27762.0
# 169  2020-06-17      210.0        34.0    33957.0
# 170  2020-06-18      328.0        43.0    32921.0
# 171  2020-06-19      331.0        66.0    28570.0
# 172  2020-06-20     -148.0        47.0    29875.0
# 173  2020-06-21      264.0        49.0    24581.0

# %% [markdown]
# #### Different ways to deal with data entry error
# We can use one of the following approaches for dealing with the missing or faulty value:
#
# - Replace it with 0.
# - Replace it with the average of the entire column
# - Replace it with the average of the values on the previous & next date
# - Discard the row entirely

# %%
# we use the .at method to replace that specific value
# wrong - covid_df.at()
covid_df.at[172, 'new_cases'] = (covid_df.at[171,'new_cases'] + covid_df.at[173, 'new_cases']) /2

# %%
covid_df.loc[172]
# Out:
# date          2020-06-20
# new_cases          297.5
# new_deaths            47
# new_tests          29875
# Name: 172, dtype: object

# %% [markdown]
# ### Working with dates

# %% [markdown]
# covid_df.date
#
# #### Query the rows for May
# covid_df_may = covid_df[covid_df.month == 5]
#
# #### Extract the subset of columns to be aggregated
# covid_df_may_metrics = covid_df_may[['new_cases', 'new_deaths', 'new_tests']]
#
# #### Get the column-wise sum
# covid_may_totals = covid_df_may_metrics.sum()
#
#
# covid_df['year'] = pd.DatetimeIndex(covid_df.date).year
# covid_df['month'] = pd.DatetimeIndex(covid_df.date).month
# covid_df['day'] = pd.DatetimeIndex(covid_df.date).day
# covid_df['weekday'] = pd.DatetimeIndex(covid_df.date).weekday
#
# covid_df['date'] = pd.to_datetime(covid_df.date)

# %% [markdown]
# #### Grouping and aggregation

# %%
covid_df["month"] = pd.DatetimeIndex(covid_df.date).month

# %%
covid_df['year'] = pd.DatetimeIndex(covid_df.date).year
covid_df['month'] = pd.DatetimeIndex(covid_df.date).month
covid_df['day'] = pd.DatetimeIndex(covid_df.date).day
covid_df['weekday'] = pd.DatetimeIndex(covid_df.date).weekday

covid_df['date'] = pd.to_datetime(covid_df.date)

# %%
# Group by on the basis month

# %%
covid_month_df = covid_df.groupby('month')[['new_cases', 'new_tests','new_deaths']].sum()
covid_month_df
# Out:
#        new_cases  new_tests  new_deaths
# month
# 1            3.0        0.0         0.0
# 2          885.0        0.0        21.0
# 3       100851.0        0.0     11570.0
# 4       101852.0   419591.0     16091.0
# 5        29073.0  1078720.0      5658.0
# 6         8217.5   830354.0      1404.0
# 7         6722.0   797692.0       388.0
# 8        21060.0  1098704.0       345.0
# 9         3297.0    54395.0        20.0
# 12           0.0        0.0         0.0

# %%
# aggregating by sum
covid_mean_df = covid_df.groupby('month')[['new_cases','new_tests']].mean()
covid_mean_df
# Out:
#          new_cases     new_tests
# month
# 1         0.096774           NaN
# 2        30.517241           NaN
# 3      3253.258065           NaN
# 4      3395.066667  38144.636364
# 5       937.838710  34797.419355
# 6       273.916667  27678.466667
# 7       216.838710  25732.000000
# 8       679.354839  35442.064516
# 9      1099.000000  54395.000000
# 12        0.000000           NaN

# %%
# cummulative sum
covid_df["cases_cum_sum"] = covid_df.new_cases.cumsum()
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  month  cases_cum_sum  \
# 0   2019-12-31        0.0         0.0        NaN     12            0.0
# 1   2020-01-01        0.0         0.0        NaN      1            0.0
# 2   2020-01-02        0.0         0.0        NaN      1            0.0
# 3   2020-01-03        0.0         0.0        NaN      1            0.0
# 4   2020-01-04        0.0         0.0        NaN      1            0.0
# ..         ...        ...         ...        ...    ...            ...
# 243 2020-08-30     1444.0         1.0    53541.0      8       267298.5
# 244 2020-08-31     1365.0         4.0    42583.0      8       268663.5
# 245 2020-09-01      996.0         6.0    54395.0      9       269659.5
# 246 2020-09-02      975.0         8.0        NaN      9       270634.5
# 247 2020-09-03     1326.0         6.0        NaN      9       271960.5
#
#     location  total_cases  total_deaths  total_tests  year  day  weekday
# ...

# %%
cases_cum_sum_df["cum_sum"] = covid_df.new_cases.cumsum()
cases_cum_sum_df
# Out:
# 0                                                          0
# 1                                                          0
# 2                                                          0
# 3                                                          0
# 4                                                          0
#                                  ...
# 244                                                   268664
# 245                                                   269660
# 246                                                   270634
# 247                                                   271960
# cum_sum    0           0.0
# 1           0.0
# 2           0....
# Name: new_cases, Length: 249, dtype: object

# %%
# to delete a column and return a new df(a copy of the original)- specify at least one of 'labels', 'index' or 'columns'
cases_cum_sum_df.drop("cum_sum",inplace=True)

# %%
cases_cum_sum_df
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#         ...
# 243    267298
# 244    268664
# 245    269660
# 246    270634
# 247    271960
# Name: new_cases, Length: 248, dtype: object

# %%
# Merging data from multiple sources
# urlretrieve(url, file location to save content)
urlretrieve("https://gist.githubusercontent.com/aakashns/8684589ef4f266116cdce023377fc9c8/raw/99ce3826b2a9d1e6d0bde7e9e559fc8b6e9ac88b/locations.csv","location.csv")
location_df = pd.read_csv("location.csv")
location_df
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                         0.500        1803.987
# 1                         2.890       11803.431
# 2                         1.900       13913.839
# 3                           NaN             NaN
# ...

# %%
location_df[location_df.location == "Italy"]
# Out:
#    location continent  population  life_expectancy  \
# 97    Italy    Europe  60461828.0            83.51
#
#     hospital_beds_per_thousand  gdp_per_capita
# 97                        3.18       35220.084

# %%
covid_df['location'] = "Italy" # to make a common column in both dataframes
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  month  cases_cum_sum  \
# 0   2019-12-31        0.0         0.0        NaN     12            0.0
# 1   2020-01-01        0.0         0.0        NaN      1            0.0
# 2   2020-01-02        0.0         0.0        NaN      1            0.0
# 3   2020-01-03        0.0         0.0        NaN      1            0.0
# 4   2020-01-04        0.0         0.0        NaN      1            0.0
# ..         ...        ...         ...        ...    ...            ...
# 243 2020-08-30     1444.0         1.0    53541.0      8       267298.5
# 244 2020-08-31     1365.0         4.0    42583.0      8       268663.5
# 245 2020-09-01      996.0         6.0    54395.0      9       269659.5
# 246 2020-09-02      975.0         8.0        NaN      9       270634.5
# 247 2020-09-03     1326.0         6.0        NaN      9       271960.5
#
#     location  total_cases  total_deaths  total_tests  year  day  weekday
# ...

# %%
covid_df['total_cases'] = covid_df.new_cases.cumsum()
covid_df['total_deaths'] = covid_df.new_deaths.cumsum()
covid_df['total_tests'] = covid_df.new_tests.cumsum()

# %% [markdown]
# ### Merging two dataframes

# %%
new_df = covid_df.merge(location_df, on ="location")
new_df
# Out:
#           date  new_cases  new_deaths  new_tests  month  cases_cum_sum  \
# 0   2019-12-31        0.0         0.0        NaN     12            0.0
# 1   2020-01-01        0.0         0.0        NaN      1            0.0
# 2   2020-01-02        0.0         0.0        NaN      1            0.0
# 3   2020-01-03        0.0         0.0        NaN      1            0.0
# 4   2020-01-04        0.0         0.0        NaN      1            0.0
# ..         ...        ...         ...        ...    ...            ...
# 243 2020-08-30     1444.0         1.0    53541.0      8       267298.5
# 244 2020-08-31     1365.0         4.0    42583.0      8       268663.5
# 245 2020-09-01      996.0         6.0    54395.0      9       269659.5
# 246 2020-09-02      975.0         8.0        NaN      9       270634.5
# 247 2020-09-03     1326.0         6.0        NaN      9       271960.5
#
#     location  total_cases  total_deaths  total_tests  year  day  weekday  \
# ...

# %%
new_df['cases_per_mil'] = new_df.total_cases * 1e6 / new_df.population

# %%
new_df['deaths_per_mil'] = new_df.total_deaths * 1e6 / new_df.population
new_df['tests_per_mil'] = new_df.total_tests * 1e6 / new_df.population

# %%
new_df
# Out:
#           date  new_cases  new_deaths  new_tests  month  cases_cum_sum  \
# 0   2019-12-31        0.0         0.0        NaN     12            0.0
# 1   2020-01-01        0.0         0.0        NaN      1            0.0
# 2   2020-01-02        0.0         0.0        NaN      1            0.0
# 3   2020-01-03        0.0         0.0        NaN      1            0.0
# 4   2020-01-04        0.0         0.0        NaN      1            0.0
# ..         ...        ...         ...        ...    ...            ...
# 243 2020-08-30     1444.0         1.0    53541.0      8       267298.5
# 244 2020-08-31     1365.0         4.0    42583.0      8       268663.5
# 245 2020-09-01      996.0         6.0    54395.0      9       269659.5
# 246 2020-09-02      975.0         8.0        NaN      9       270634.5
# 247 2020-09-03     1326.0         6.0        NaN      9       271960.5
#
#     location  total_cases  total_deaths  total_tests  ...  day  weekday  \
# ...

# %% [markdown]
# ### Writing data back to files after making the changes
# - passing the relevant columns to a new df
#     result_df = merged_df[['date',
#                        'new_cases',
#                        'total_cases',
#                        'new_deaths',
#                        'total_deaths',
#                        'new_tests',
#                        'total_tests',
#                        'cases_per_million',
#                        'deaths_per_million',
#                        'tests_per_million']]
#
# - result_df.to_csv('results.csv', index=None)

# %%
result_df = new_df[['date',
                       'new_cases', 
                       'total_cases', 
                       'new_deaths', 
                       'total_deaths', 
                       'new_tests', 
                       'total_tests', 
                       'cases_per_mil', 
                       'deaths_per_mil', 
                       'tests_per_mil']]

result_df.to_csv('results.csv', index=None)

# %% [markdown]
# #### Basic plotting with pandas

# %%
#df.col.plot() - line graph
new_df.new_cases.plot()
result_df.set_index('date', inplace =True)

# %%
new_df.loc['2020-09-01']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._maybe_get_bool_indexer()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '2020-09-01'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
new_df.new_cases.plot()
new_df.new_deaths.plot();

# %%
new_df.total_cases.plot()
new_df.total_deaths.plot();

# %%
death_rate = result_df.total_deaths / result_df.total_cases
death_rate
death_rate.plot(title = 'Death Rate')
# Out:
# <AxesSubplot:title={'center':'Death Rate'}, xlabel='date'>

# %%
covid_month_df.new_cases.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='month'>

# %%
new_df['total_cases'].unique()
# unique() - returns a list containing all the unique elements
# Out:
# array([0.000000e+00, 3.000000e+00, 1.700000e+01, 7.900000e+01,
#        1.320000e+02, 2.290000e+02, 3.220000e+02, 4.000000e+02,
#        6.500000e+02, 8.880000e+02, 1.128000e+03, 1.689000e+03,
#        2.036000e+03, 2.502000e+03, 3.089000e+03, 3.858000e+03,
#        4.636000e+03, 5.883000e+03, 7.375000e+03, 9.172000e+03,
#        1.014900e+04, 1.246200e+04, 1.511300e+04, 1.766000e+04,
#        2.115700e+04, 2.398000e+04, 2.798000e+04, 3.150600e+04,
#        3.571300e+04, 4.103500e+04, 4.702100e+04, 5.357800e+04,
#        5.913800e+04, 6.392700e+04, 6.917600e+04, 7.438600e+04,
#        8.053900e+04, 8.649800e+04, 9.247200e+04, 9.768900e+04,
#        1.017390e+05, 1.057920e+05, 1.105740e+05, 1.152420e+05,
#        1.198270e+05, 1.246320e+05, 1.289480e+05, 1.325470e+05,
#        1.355860e+05, 1.394220e+05, 1.436260e+05, 1.475770e+05,
#        1.522710e+05, 1.563630e+05, 1.595160e+05, 1.624880e+05,
#        1.651550e+05, 1.689410e+05, 1.724340e+05, 1.759250e+05,
# ...
